# %% [markdown]
# <a href="https://colab.research.google.com/github/zhinanakhaei/Zhina-/blob/main/Zhina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#تمرین_یک
student_name = "ژینا"
subject = "اقتصاد"
sleep_hours = 4
print(f"😴 {student_name} فقط {sleep_hours} ساعت خوابید چون امتحان {subject} داشت!")
# Out:
# 😴 ژینا فقط 4 ساعت خوابید چون امتحان اقتصاد داشت!

# %%
#تفریق_تقسیم_روی_لیست_کار_نمیکنه
grades_zhina = [18, 19, 17]
grades_friend = [16, 15, 18]
print( grades_zhina + grades_friend)
print( grades_zhina * 2)
#print( grades_zhina - grades_friend)
#print( grades_zhina / grades_friend)
# Out:
# [18, 19, 17, 16, 15, 18]
# [18, 19, 17, 18, 19, 17]
